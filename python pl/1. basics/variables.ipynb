# %%
# declaring and assigning variales
# python doesnt need declaration of data type and memory size

## var naming conventions
# var name should be desctiptive
# they must star with a letter or an "_" 
# var only contains 1)letter, 2)numb, 3)underscores

#assigning variables
age = 32
height = 5.7
name = "farane"
is_student = True
#printing variables
print("age : ",age)
print("height :", height)
print("name is:" , name)
# Out:
# age :  32
# height : 5.7
# name is: farane

# %%
## Understanding variable types

# python is dynamically typed, type of variable is determined at runtime
var = 10
print(type(var))
var = "hello"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Type checking and conversion
age = 35
age_str = str(age)
print(age)
print(type(age))
print(age_str)
print(type(age_str))
# Out:
# 35
# <class 'int'>
# 35
# <class 'str'>

# %%
age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "farabe"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 name = "farabe"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'farabe'

# %%
weight =  70.8
type(weight)
# Out:
# float

# %%
int(weight)
# Out:
# 70

# %%
float(age)
# Out:
# 25.0

# %%
## Dynamic Typing
# python allows changing the type of a varianle as the program executes

var =35
print(var, type(var))

var = 55.9
print(var, type(var))

var = "hello"
print(var, type(var))
# Out:
# 35 <class 'int'>
# 55.9 <class 'float'>
# hello <class 'str'>

# %%
## Input

age=input("whats the age")
print(age, type(age))
# Out:
# helo <class 'str'>

# %%
age=int(input("whats the age"))
print(age, type(age))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 age=int(input("whats the age"))
#       2 print(age, type(age))
#
# ValueError: invalid literal for int() with base 10: 'hello'
