# %% [markdown]
# ### Sets

# %% [markdown]
# ## like c++, pythonic set is not sorted, rather it stores elements in a arbitary order
# in sets items are unordered, unique element.
# meaning they stores as sorted and no duplicate element.
# this is useful for union,intersection,difference,symmetric difference

# %%
### create a set
my_set = {1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_empty_set = set()

# %%
### typcasting to set
my_set = set([1,2,3,4,5])
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_set = set([5,6,7,5,6,7,6,5,6,7,7,6])
print(my_set)
# Out:
# {5, 6, 7}

# %%
## basic set operation
# adding element

my_set.add(8)
print(my_set)
my_set.add(7)
print(my_set)
# Out:
# {8, 5, 6, 7}
# {8, 5, 6, 7}

# %%
# removing element
my_set.remove(7)
print(my_set)
# Out:
# {8, 5, 6}

# %%
my_set.remove(10)
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 my_set.remove(10)
#       2 print(my_set)
#
# KeyError: 10

# %%
my_set.discard(10)
print(my_set)
# Out:
# {8, 5, 6}

# %%
## pop arbitarily removed anu element
removed_element = my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 8
# {5, 6}

# %%
my_set.clear()
print(my_set)

# %%
## set membership test
my_set = set([5,6,7,5,6,7,6,5,6,7,7,6])
print(5 in my_set)
print(10 in my_set)
# Out:
# True
# False

# %%
## mathematical operation

set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

#union
union_set = set1.union(set2)
print(union_set)

# Intersection
inter_set = set1.intersection(set2)
print(inter_set)

# update the first set with the set operation result
set1.intersection_update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {4, 5, 6}

# %%
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

# Difference
diff_set = set1.difference(set2)
print(diff_set)
print(set2.difference(set1))
# Out:
# {1, 2, 3}
# {8, 9, 7}

# %%
## symmetric difference
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
## Set methods
set1 = {1,2,3}
set2 = {3,4,5}

#is subset
print(set1.issubset(set2))
#is superset
print(set1.issuperset(set2))
# Out:
# False
# False

# %%
## Set methods
set1 = {1,2,3,4,5}
set2 = {3,4,5}

#is subset
print(set1.issubset(set2))
#is superset
print(set1.issuperset(set2))
# Out:
# False
# True

# %%
lst = [1,2,2,3,4,4,5]
print(set(lst))
# Out:
# {1, 2, 3, 4, 5}

# %%
### counting unique words in text
text  = "in this tutorial we are discussing about sets"
words = text.split()

unique_words = set(words)

print(unique_words)
print(len(unique_words))
# Out:
# {'we', 'in', 'this', 'discussing', 'tutorial', 'are', 'about', 'sets'}
# 8
