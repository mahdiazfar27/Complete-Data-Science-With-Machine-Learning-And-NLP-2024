# %% [markdown]
# ### for creating an environment:

# %% [markdown]
# conda create -p env_name python==3.12

# %% [markdown]
# ### to activate the venv

# %% [markdown]
# conda activate env_name/

# %% [markdown]
# ### to deactivate

# %% [markdown]
# conda deactivate

# %% [markdown]
# ### for .ipynb file to run python code we need to install "ipykernel" library which we can write to requiremets.txt

# %% [markdown]
# pip install -r requirements.txt
