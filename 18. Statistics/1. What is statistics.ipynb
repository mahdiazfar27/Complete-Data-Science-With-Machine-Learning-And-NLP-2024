# %% [markdown]
# ## What is Statistics and its Application?
#
# **Statistics** is a field that deals with **collection**, **organization**, **analysis**, **interpretation**, and **presentation** of the data.
#
# $$\Downarrow$$
#
#                             ## to Understand & Decision Making

# %% [markdown]
# ## Application
#
# * 1. Every one uses it
#
#
# * 2. Machine learning
#
#
# * 3. DATA Analyst
#
#
# * 4. Bussiness Analytics
#
#
# * 5. Risk Analyst
#
#
# * 6. House wife
#
#
# * 7. In Every Domain & field
