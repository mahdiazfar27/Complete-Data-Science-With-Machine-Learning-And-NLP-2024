# %% [markdown]
# ### Standard library

# %% [markdown]
# pythons standard library is a vast collection of modules and packages that come bundled with python, providing a wide range of functionalities out of the box. here's an overview of some of them which are commonly used.

# %%
### array module from python standard library
import array
arr = array.array('i', [1,2,3,4,5]) # here 'i' stands for integer the data tupes of the array elemtents.
print(arr)

# array is like a list but- 
    # 1) it stores same data types only
    # 2) more memory efficient
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
### random
import random
print(random.randint(1,10)) #inclusive range
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 4
# apple

# %%
### OS
# veru common library we use for file and directory access

import os
print(os.getcwd())
# Out:
# f:\Complete-Data-Science-With-Machine-Learning-And-NLP-2024\python_programming_language\5. modules

# %%
os.mkdir('folder_creating_using_os')

# %%
### shutil
# High level operations on - files and collection of files
import shutil
shutil.copyfile('shutil_main.txt', 'shutil_copy.txt')
# Out:
# 'shutil_copy.txt'

# %%
### json
### Data Serialization
#when we retrive any data from server using API we get the data in terms of json file (no sql)
import json
data = {'name': 'farabe', 'age': 25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

# after api call we will get this json_str
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "farabe", "age": 25}
# <class 'str'>
# {'name': 'farabe', 'age': 25}
# <class 'dict'>

# %%
### csv
import csv
with open('example.csv', mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['farabe', 25])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['farabe', '25']

# %%
### datetime
from datetime import datetime, timedelta
now = datetime.now()
print(now)
yesterday = now - timedelta(days = 2)
print(yesterday)
# Out:
# 2026-03-18 15:01:51.804120
# 2026-03-16 15:01:51.804120

# %%
### time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1773824554.0667193
# 1773824556.0674355

# %%
### re
# regular expression
import re
pattern = r'\d+'
text = 'there are 1234 apples 456'
match = re.search(pattern, text)
print(match.group())
# Out:
# 1234
