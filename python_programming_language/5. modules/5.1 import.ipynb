# %% [markdown]
# ### importing modules and packages in python

# %% [markdown]
# python hierarchy:
# Library     ### collection of packages e.g. scikit-learn,pandas ### we install libraries using <pip install library_name>
#     package     ### it's folders of modules e.g. sklear.preprocessing ###
#         module      ### it's a single .py files e.g. math.py ###
#             function/class      ### defined inside module e.g. sqrt() ### we import these packages, modules, fucn to our code using <import package/module_name as alias>
#                 statements      ### actual lines of codes ###

# %%
### importing package 
# import package_name as alias_name 
# (alias_name is the optional name we want to use to refer to the package in our code)
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
### importing function from package
# from package_name import function_name 
# and here alias_name is not optional because we have to use the function name to refer to the function in our code.
 
from math import sqrt, pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %% [markdown]
# ### here in the code:
# library -> python standard library
# module -> math
# function -> sqrt()

# %%
## Most important modules are: 
# math (mathematical operations): provides mathematical functions and constants.
# os (operating system functions): provides a way to interact with the operating system.
# sys (system-specific parameters): provides access to system-specific parameters and functions. system-specific parameters are parameters that are specific to the operating system or environment in which the Python interpreter is running. These parameters can include things like the path to the Python executable, the version of Python being used, and the platform on which the code is running.
# datetime (date and time handling): provides classes for manipulating dates and times.
# json (JSON data handling): provides functions for working with JSON data.
# requests (HTTP requests): provides a simple way to make HTTP requests.
# numpy (numerical computing for arrays and matrices): provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.
# pandas (data manipulation): provides data structures and functions for manipulating structured data.
# matplotlib (plotting): provides a comprehensive library for creating static, animated, and interactive visualizations in Python.
# seaborn (statistical data visualization): provides a high-level interface for drawing attractive and informative statistical graphics.
# scikit-learn (machine learning): provides simple and efficient tools for data mining and data analysis.
# tensorflow (deep learning): provides a comprehensive library for building and training deep learning models.
# keras (neural networks): provides a high-level neural networks API that can run on top of TensorFlow.
# pytorch (deep learning): provides a deep learning framework for building and training neural networks.
# nltk (natural language processing): provides a set of programming interfaces for natural language processing tasks.
# spacy (natural language processing): provides a modern natural language processing library for Python.
# gensim (topic modeling and document similarity): provides a library for topic modeling and document similarity analysis.
# beautifulsoup4 (web scraping): provides a simple way to parse HTML and XML documents.
# scrapy (web scraping): provides a powerful framework for extracting data from websites.
# flask (web framework): provides a lightweight web application framework.
# django (web framework): provides a high-level Python web framework that encourages rapid development and clean, pragmatic design.
# fastapi (web framework): provides a modern, fast (high-performance) web framework for building APIs with Python 3.7+ based on standard Python type hints.
# etc are also important modules but these are the most commonly used ones.

# %%
import numpy as np ## np is just a shortcut to call its functions , we can use any name we want but np is the convention used by most data scientists and machine learning engineers. its called aliasing.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import numpy as np ## np is just a shortcut to call its functions
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# after pip install -r requirement.txt in the env_name environment
# or %pip install numpy
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *     
# * imports all functions from math import sqrt, pi  
# this will override the previous import and we can use sqrt and pi without the math. prefix 
# but it is not recommended to use * because it can cause conflicts with other functions that have the same name in other packages. it can also make it harder to read the code and understand where the functions are coming from. 
# so it is better to import only the functions that we need or to use an alias for the package.

print(sqrt(36))
print(pi)
# Out:
# 6.0
# 3.141592653589793

# %%
### now importing my own module(.py file) form my own_package(folder)
# but this import.ipynb(name of this file) and the own_pakage folder shoud be in same directory

from own_package.maths import add
print(add(3,4))
# Out:
# 7

# %%
# another way to call the function from the package is to import the whole module and then call the function using the module name as a prefix. 
# this is useful when we have multiple functions in the module and we want to avoid conflicts with other functions that have the same name in other packages.

from own_package import maths
print(maths.add(4,6))
# Out:
# 10
