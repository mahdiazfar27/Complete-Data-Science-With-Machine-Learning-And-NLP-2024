# %% [markdown]
# ### DataTypes

# %%
## Common errors
result = "hello" + 27
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 ## Common errors
# ----> 2 result = "hello" + 27
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello" + str(27)
print(result)
# Out:
# hello27

# %%
str = "hello"
# str. this str class has a lot of methods
str.method_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 str = "hello"
#       2 # str. this str class has a lot of methods
# ----> 3 str.method_name()
#
# AttributeError: 'str' object has no attribute 'method_name'
